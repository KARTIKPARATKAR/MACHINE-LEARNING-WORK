# %% [markdown]
# <a href="https://colab.research.google.com/github/KARTIKPARATKAR/MACHINE-LEARNING-WORK/blob/main/GradientDescent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Model Optimization-***
#
# Optimiztion refers to determining best parameters for a model,such that the loss function of the model decreases,as a result of which the model can predict more accurately.
# Parameters are Weights and Biases.
#
# ***Gradient Descent-***
#
# Gradient Descent is an optimization algorithm used to minimize a loss function by iteratively updating the model’s parameters (weights and biases). It is widely used in machine learning for training models, especially in linear regression, logistic regression, and neural networks.
#
# ![7.jpg](data:image/jpeg;base64,...)
#
# Observe above graph. Let we have a ML-Model which has loss function() and different input weights w1,w2 and w10.  We are desired to have a less loss function so as to get higher accuracy of model prediction. Consider w1 as the initial weight,but it has higher weight value so we will change the weight value slowly to get the more possible lower values by changing the weight values step-by-step. We reach to weight value of w3 where loss function has the lower value, so we wil finalize the w3 as weight value. It doesnt matter where you start your weight value from w1 or w10 , you are intended to find the weight value where loss function has the lowest value and it is w3. SO this changing the weight value step-by-step is known as Gradient Descent.
#
#
# ![8.jpg](data:image/jpeg;base64,...)
